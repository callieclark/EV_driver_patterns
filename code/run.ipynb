# %%
# !pip install pydeck -q -q
# !pip install censusdata
# !pip install statsmodels
# !pip install fastparquet
# !pip install pyarrow
#!pip install polars
#!pip install seaborn

# %%
exec(open('EV00_settings.py').read())

# %%
current_city #SF, Seattle, Denver, Boston

# %%
# !ipython EV01_pull_ping_data.ipy

# %%
# !python EV02_process_ping_data.py

# %%
# !ipython EV03_pull_stop_data.ipy

# %%
# !ipython EV04A_user_ping_rate_stats.ipy

# %%
# !ipython EV04B_filter_users.ipy

# %%
# !python EV04C_filter_users.py

# %%
# !python EV05_combine_EV_stations.py

# %%
# !python EV05B_create_evcs_nearby_dict.py

# %%
# !python EV06_create_EVCS_slow_points.py

# %%
# !python EV07_create_EVCS_sessions.py

# %%
# !python EV08_create_gas_sessions.py

# %%
# !python EV09_create_model_inputs.py

# %%
# !python EV10_filter_EV_drivers_model.py

# %%
# !python EV11_identify_session_stops.py

# %%
# !python EV11A_identify_poi_stops.py

# %%
# !python EV99_fill_unobserved_points.py
